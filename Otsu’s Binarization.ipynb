# %% [markdown]
# # first
#   Show the images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
gimg = cv2.imread('assignment 1/swan.pgm',0)
gimg1 = cv2.imread('assignment 1/tools.pgm',0)
gimg2 = cv2.imread('assignment 1/flower.pgm',0)
hist=plt.hist(gimg.ravel(),256,[0,256])#here by the matplotlib to do histogram
hist1=plt.hist(gimg1.ravel(),256,[0,256])#here by the matplotlib to do histogram
hist2=plt.hist(gimg2.ravel(),256,[0,256])#here by the matplotlib to do histogram

plt.subplot(231),plt.imshow(gimg,'gray'),plt.title('swan')                   
plt.xticks([]), plt.yticks([])
plt.subplot(232),plt.imshow(gimg1,'gray'),plt.title('tools')
plt.xticks([]), plt.yticks([])
plt.subplot(233),plt.imshow(gimg2,'gray'),plt.title('flower')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# # Histogram for each image
#
# I explained previously . in anaconad 1

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
gimg = cv2.imread('assignment 1/swan.pgm',0)
gimg1 = cv2.imread('assignment 1/tools.pgm',0)
gimg2 = cv2.imread('assignment 1/flower.pgm',0)

plt.hist(gimg.ravel(),256,[0,256]),plt.title("Histogram for Swan Image"),plt.show();
plt.hist(gimg1.ravel(),256,[0,256]),plt.title("Histogram for tools Image"),plt.show();
plt.hist(gimg2.ravel(),256,[0,256]),plt.title("Histogram for flower Image"),plt.show();

# %% [markdown]
# # Otsu’s Binarization
# in simple words, it automatically calculates a threshold value from image histogram for a bimodal image. Then the algorithm finds the optimal threshold value and returns you as the second output.

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('assignment 1/flower.pgm',0)
# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('assignment 1/swan.pgm',0)
# global thresholding
ret1,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
# Otsu's thresholding
ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(img,(5,5),0)
ret3,th3 = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
# plot all the images and their histograms
images = [img, 0, th1,
          img, 0, th2,
          blur, 0, th3]
titles = ['Original Noisy Image','Histogram','Global Thresholding (v=127)',
          'Original Noisy Image','Histogram',"Otsu's Thresholding",
          'Gaussian filtered Image','Histogram',"Otsu's Thresholding"]
for i in range(3):
    plt.subplot(3,3,i*3+1),plt.imshow(images[i*3],'gray')
    plt.title(titles[i*3]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+2),plt.hist(images[i*3].ravel(),256)
    plt.title(titles[i*3+1]), plt.xticks([]), plt.yticks([])
    plt.subplot(3,3,i*3+3),plt.imshow(images[i*3+2],'gray')
    plt.title(titles[i*3+2]), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('assignment 1/tools.pgm',0)
img = cv2.medianBlur(img,5)
ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)
titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]
for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()
